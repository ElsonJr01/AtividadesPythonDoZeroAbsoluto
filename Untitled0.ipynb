# %% [markdown]
# <a href="https://colab.research.google.com/github/ElsonJr01/AtividadesPythonDoZeroAbsoluto/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importar as bibliotecas necessárias
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# Dados de treinamento (temperaturas)
celsius = np.array([-40, -10, 0, 8, 15, 22, 38], dtype=float)
fahrenheit = np.array([-40, 14, 32, 46.4, 59, 71.6, 100], dtype=float)

# Criar o modelo de rede neural
model = tf.keras.Sequential([
    tf.keras.layers.Dense(units=1, input_shape=[1])
])

# Compilar o modelo
model.compile(
    optimizer=tf.keras.optimizers.Adam(0.1),
    loss='mean_squared_error'
)

# Treinar o modelo
print("Treinando o modelo...")
hist = model.fit(celsius, fahrenheit, epochs=500, verbose=False)
print("Treinamento concluído!")

# Plotar gráfico do histórico de treinamento
plt.figure(figsize=(10,5))
plt.plot(hist.history['loss'])
plt.title("Histórico de Treinamento (Loss por Epoch)")
plt.xlabel("Épocas")
plt.ylabel("Perda (Loss)")
plt.grid(True)
plt.show()

# Testar com novos dados (não presentes no treinamento)
novas_temperaturas = np.array([-20, -5, 5, 12, 18, 25, 30, 35, 40, 45], dtype=float)
valores_previstos = model.predict(novas_temperaturas)

# Calcular os valores reais para comparação
valores_reais = novas_temperaturas * 1.8 + 32

# Criar a tabela comparativa
tabela = pd.DataFrame({
    "Celsius": novas_temperaturas,
    "Previsto (F)": np.round(valores_previstos.flatten(), 2),
    "Real (F)": np.round(valores_reais, 2)
})

print("\nTabela Comparativa - Resultados do Modelo")
print(tabela)
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Treinando o modelo...
# Treinamento concluído!
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
#
# Tabela Comparativa - Resultados do Modelo
#    Celsius  Previsto (F)  Real (F)
# 0    -20.0     -8.060000      -4.0
# 1     -5.0     19.340000      23.0
# 2      5.0     37.610001      41.0
# 3     12.0     50.389999      53.6
# 4     18.0     61.349998      64.4
# 5     25.0     74.139999      77.0
# 6     30.0     83.269997      86.0
# 7     35.0     92.410004      95.0
# 8     40.0    101.540001     104.0
# 9     45.0    110.669998     113.0
